# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"
messages = []


def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

add_user_message(
    messages,
    "Write a Python function that checks a string for duplicate characters",
)
answer = chat(messages)
answer
# Out:
# '## Checking for Duplicate Characters in a String\n\nHere\'s a Python function that checks a string for duplicate characters, along with several variations:\n\n```python\ndef has_duplicates(string: str) -> bool:\n    """\n    Check if a string contains any duplicate characters.\n    \n    Args:\n        string: The input string to check.\n    \n    Returns:\n        True if duplicates exist, False otherwise.\n    """\n    return len(string) != len(set(string))\n\n\ndef find_duplicates(string: str) -> set:\n    """\n    Find and return all duplicate characters in a string.\n    \n    Args:\n        string: The input string to check.\n    \n    Returns:\n        A set of duplicate characters.\n    """\n    seen = set()\n    duplicates = set()\n\n    for char in string:\n        if char in seen:\n            duplicates.add(char)\n        else:\n            seen.add(char)\n\n    return duplicates\n\n\ndef count_duplicates(string: str) -> dict:\n    """\n    Count the occurrences of each duplicate character in a string.\n    \n    Args:\n        string: The input string to check.\n    \n    Returns:\n        A dictionary with duplicate characters as keys and their counts as values.\n    """\n    char_count = {}\n\n    for char in string:\n        char_count[char] = char_count.get(char, 0) + 1\n\n    return {char: count for char, count in char_count.items() if count > 1}\n\n\ndef check_duplicates(string: str, case_sensitive: bool = True) -> dict:\n    """\n    Comprehensive duplicate character checker.\n    \n    Args:\n        string: The input string to check.\n        case_sensitive: Whether the check should be case-sensitive (default: True).\n    \n    Returns:\n        A dictionary with the results of the check.\n    """\n    if not case_sensitive:\n        string = string.lower()\n\n    duplicates = count_duplicates(string)\n\n    return {\n        "has_duplicates": bool(duplicates),\n        "duplicate_chars": duplicates,\n        "total_duplicates": sum(duplicates.values()),\n        "unique_chars": len(set(string)),\n        "total_chars": len(string),\n    }\n\n\n# --- Example Usage ---\nif __name__ == "__main__":\n    test_strings = ["hello", "world", "python", "abcdef", "mississippi"]\n\n    for s in test_strings:\n        print(f"\\nString: \'{s}\'")\n        print(f"  Has duplicates    : {has_duplicates(s)}")\n        print(f"  Duplicate chars   : {find_duplicates(s)}")\n        print(f"  Duplicate counts  : {count_duplicates(s)}")\n        print(f"  Full report       : {check_duplicates(s)}")\n```\n\n### Output\n\n```\nString: \'hello\'\n  Has duplicates    : True\n  Duplicate chars   : {\'l\'}\n  Duplicate counts  : {\'l\': 2}\n  Full report       : {\'has_duplicates\': True, \'duplicate_chars\': {\'l\': 2}, \'total_duplicates\': 2, \'unique_chars\': 4, \'total_chars\': 5}\n\nString: \'world\'\n  Has duplicates    : False\n  Duplicate chars   : set()\n  Duplicate counts  : {}\n  Full report       : {\'has_duplicates\': False, \'duplicate_chars\': {}, \'total_duplicates\': 0, \'unique_chars\': 5, \'total_chars\': 5}\n\nString: \'python\'\n  Has duplicates    : False\n  Duplicate chars   : set()\n  Duplicate counts  : {}\n  Full report       : {\'has_duplicates\': False, \'duplicate_chars\': {}, \'total_duplicates\': 0, \'unique_chars\': 6, \'total_chars\': 6}\n\nString: \'abcdef\'\n  Has duplicates    : False\n  Duplicate chars   : set()\n  Duplicate counts  : {}\n  Full report       : {\'has_duplicates\': False, '
