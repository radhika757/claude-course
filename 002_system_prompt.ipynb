# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"
messages = []


def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def chat(messages, system=None):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        system=system
    )
    return message.content[0].text

add_user_message(
    messages,
    "Write a Python function that checks a string for duplicate characters",
)
answer = chat(messages, system = "You are a python engineer, who writea very concise code")
answer
# Out:
# '```python\ndef has_duplicates(s: str) -> bool:\n    return len(s) != len(set(s))\n```\n\n**Examples:**\n```python\nprint(has_duplicates("hello"))   # True  (\'l\' repeated)\nprint(has_duplicates("world"))   # False\nprint(has_duplicates("python"))  # False\nprint(has_duplicates("abcca"))   # True  (\'a\', \'c\' repeated)\n```\n\nIf you also want to **find which characters are duplicated**:\n\n```python\ndef find_duplicates(s: str) -> set:\n    seen = set()\n    return {c for c in s if c in seen or seen.add(c)}\n\nprint(find_duplicates("hello"))  # {\'l\'}\nprint(find_duplicates("abcca"))  # {\'a\', \'c\'}\n```'
